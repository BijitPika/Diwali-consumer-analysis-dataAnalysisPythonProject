# %% [markdown]
# Load Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install -q kaggle

# %% [markdown]
# Select path and store it in a variable if the file is Google Drive.

# %%
path = '/content/drive/MyDrive/CSV/Diwali.csv'

# %% [markdown]
# Using encoding as 'unicode_escape'

# %%
df = pd.read_csv(path, encoding='unicode_escape')

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head(5)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %% [markdown]
# Detecting NULL Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# Dropping NULL Values 'Status' and 'unnamed1'

# %%
df.drop(['Status', 'unnamed1'], axis=1 , inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.shape
# Out:
# (11251, 13)

# %%
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df.shape
# Out:
# (11239, 13)

# %% [markdown]
# Changing 'Amount' type to 'int'

# %%
df['Amount']=df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.head(10)
# Out:
#     User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0   1002903  Sanskriti  P00125942      F     26-35   28               0
# 1   1000732     Kartik  P00110942      F     26-35   35               1
# 2   1001990      Bindu  P00118542      F     26-35   35               1
# 3   1001425     Sudevi  P00237842      M      0-17   16               0
# 4   1000588       Joni  P00057942      M     26-35   28               1
# 5   1000588       Joni  P00057942      M     26-35   28               1
# 6   1001132       Balk  P00018042      F     18-25   25               1
# 8   1003224     Kushal  P00205642      M     26-35   35               0
# 9   1003650      Ginny  P00031142      F     26-35   26               1
# 10  1003829   Harshita  P00200842      M     26-35   34               0
#
#                State      Zone       Occupation Product_Category  Orders  \
# 0        Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# **Total sales by Gender**

# %%
ax = sns.countplot( x= 'Gender', data=df, hue='Gender' )
sns.set(rc={'figure.figsize':(6,5)})
for bars in ax.containers:
  ax.bar_label(bars)

# %% [markdown]
# *Above Graph shows that most of the Customers are 'Females'.*

# %% [markdown]
# Sales by Gender and Age Group

# %%
ax = sns.countplot( x= 'Age Group', data=df , hue='Gender')
sns.set(rc={'figure.figsize':(10,5)})
for bars in ax.containers:
  ax.bar_label(bars)

# %% [markdown]
# *Above Data States that most of the customers are from age group of '26-35' where most of the customers are females.*

# %% [markdown]
# **Sales by Amount and Age group**

# %%
sales_age = df.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot (x='Age Group', y='Amount', data= sales_age, hue="Age Group" )
sns.set(rc={'figure.figsize':(5,5)})

# %% [markdown]
# Above data states that most money spent is among the age group of 26-25, 36-45 and 18-25

# %% [markdown]
# **Total sales by State**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
sales_state = df.groupby(['State'],as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state,x='State',y='Orders',hue='State')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %% [markdown]
# Above data shows that Uttar Pradesh, Maharashtra and Karnataka are among the top states who spent the most in Diwali.

# %% [markdown]
#  **Sale by Marital Status**

# %%
ax = sns.countplot(data=df,x='Marital_Status',hue="Marital_Status")
sns.set(rc={'figure.figsize':(5,5)})
for bars in ax.containers:
  ax.bar_label(bars)

# %% [markdown]
# *Above data States that most of the customers are Married.*

# %%
sales_state = df.groupby(['Marital_Status',"Gender"],as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(data = sales_state,x='Marital_Status',y='Amount',hue='Gender')
sns.set(rc={'figure.figsize':(5,5)})

# %% [markdown]
# *Most of the married customers are Female.*

# %% [markdown]
# **Sales by Occupation**

# %%
ax= sns.countplot(data=df,x='Occupation',hue='Occupation')
sns.set(rc={'figure.figsize':(27,5)})
for bars in ax.containers:
  ax.bar_label(bars)

# %% [markdown]
# *Above data states shows the most occupation that spent on diwali.*

# %%
sales_state = df.groupby(['Occupation'],as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(data=sales_state,x='Occupation',y='Amount',hue='Occupation')
sns.set(rc={'figure.figsize':(27,5)})

# %% [markdown]
# *Above data states that most customer works in IT Sector, Healthcare and Aviation.*

# %% [markdown]
# **Sales by Product Category**

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
ax=sns.countplot (data=df,x = 'Product_Category', hue='Product_Category')
sns.set(rc={'figure.figsize':(30,6)})
for bars in ax.containers:
  ax.bar_label(bars)

# %% [markdown]
# *Above data shows the types of Product that are most bought.*

# %%
sales_state = df.groupby(['Product_Category'],as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.barplot(data=sales_state,x='Product_Category',y='Amount',hue='Product_Category')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# *Above data states that most amount spent of product falls in the category of Food, Clothing and Electronics.*

# %% [markdown]
# **Sale by Product ID**

# %%
sales_state = df.groupby(['Product_ID'],as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(20)
sns.barplot(data=sales_state,x='Product_ID',y='Orders',hue='Product_ID')
sns.set(rc={'figure.figsize':(26,6)})

# %% [markdown]
# *Above Data Shows the most bought product during Diwali.*

# %% [markdown]
# # **Conslusion :**
#
# The above analysis indicates that ***married women aged 26-35***, primarily from the states of ***Uttar Pradesh, Maharashtra, and Karnataka***, and working in the ***IT sector, healthcare, and aviation industries***, were the most active consumers. Their purchases predominantly comprised products in the categories of ***food, footwear, and electronics.***
